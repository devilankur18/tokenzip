# %% [markdown]
# # 🗜️ TokenZip: The Semantic Compression Layer for AI
#
# This notebook demonstrates how to use **TokenZip** to index a repository and generate "Skeletons" to save tokens when working with AI agents.
#
# ## 🚀 Setup

# %%
# !npm install -g tokenzip
# !tokenzip --version

# %% [markdown]
# ## 📂 Clone a Sample Repository
# We'll use a small repository to demonstrate the indexing process.

# %%
# !git clone https://github.com/ankur/tokenzip.git sample-repo
# %cd sample-repo

# %% [markdown]
# ## 🏗️ Initialize & Parse
# Build the knowledge graph.

# %%
# !tokenzip init
# !tokenzip parse

# %% [markdown]
# ## 💀 Generate a Skeleton
# See how TokenZip prunes implementation details to save context.

# %%
# Read a file in 'skeleton' mode
# !tokenzip smart-read src/cli/index.ts --mode skeleton

# %% [markdown]
# ## 📊 Token Efficiency Report
# Check how many tokens you are saving across the entire repo.

# %%
# !tokenzip report
